# %% [markdown]
# ### Write OOP classes to handle the following scenarios:
#
# - A user can create and view 2D coordinates
# - A user can find out the distance between 2 coordinates
# - A user can find find the distance of a coordinate from origin
# - A user can check if a point lies on a given line
# - A user can find the distance between a given 2D point and a given line

# %%
class Point:

  def __init__(self,x,y):
    self.x_cod = x
    self.y_cod = y

  def __str__(self):
    return '<{},{}>'.format(self.x_cod,self.y_cod)

  def euclidean_distance(self,other):
    return ((self.x_cod - other.x_cod)**2 + (self.y_cod - other.y_cod)**2)**0.5

  def distance_from_origin(self):
    return (self.x_cod**2 + self.y_cod**2)**0.5
    # return self.euclidean_distance(Point(0,0))

class Line:

  def __init__(self,A,B,C):
    self.A = A
    self.B = B
    self.C = C

  def __str__(self):
    return '{}x + {}y + {} = 0'.format(self.A,self.B,self.C)

  def point_on_line(line,point):
    if line.A*point.x_cod + line.B*point.y_cod + line.C == 0:
      return "lies on the line"
    else:
      return "does not lie on the line"

  def shortest_distance(line,point):
    return abs(line.A*point.x_cod + line.B*point.y_cod + line.C)/(line.A**2 + line.B**2)**0.5

# %%
l1 = Line(1,1,-2)
p1 = Point(1,10)
print(l1)
print(p1)

l1.shortest_distance(p1)

# 1x + 1y + -2 = 0
# <1,10>
# 6.363961030678928
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 l1 = Line(1,1,-2)
#       2 p1 = Point(1,10)
#       3 print(l1)
#
# NameError: name 'Line' is not defined

# %% [markdown]
# ### How objects access attributes

# %%
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country == 'india':
      print('Namaste',self.name)
    else:
      print('Hello',self.name)

# %%
 # how to access attributes
p = Person('nitish','india')
p

# <__main__.Person at 0x22e07388590>

# %%
print (p.name)
print (p.country)


# nitish
# india
# Out:
# nitish
# india

# %%
# how to access methods
p.greet()
# Namaste nitish
# Out:
# Namaste nitish

# %%
# what if i try to access non-existent attributes
p.gender

# AttributeError: 'Person' object has no attribute 'gender'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # what if i try to access non-existent attributes
# ----> 2 p.gender
#       4 # AttributeError: 'Person' object has no attribute 'gender'
#
# AttributeError: 'Person' object has no attribute 'gender'

# %% [markdown]
# ### Attribute creation from outside of the class

# %%
p.gender = 'male'

# %%
p.gender
# 'male'
# Out:
# 'male'

# %% [markdown]
# ### Reference Variables
#
# - ### Reference variables hold the objects
# - ### We can create objects without reference variable as well
# - ### An object can have multiple reference variables
# - ### Assigning a new reference variable to an existing object does not create a new object

# %%
# object without a reference
class Person:

  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'
Person()

# <__main__.Person at 0x216106f1fd0>

# %%
p = Person()
q = p
q
# <__main__.Person at 0x2161027b110>

# %%
# Multiple ref
print(id(p))
print(id(q))

# 2293783572752
# 2293783572752


# so p is just a variable name p is storing a refrence / id  of Object of Person () ,
#  p contain memory of object
# Out:
# 2293783572752
# 2293783572752

# %%
# change attribute value with the help of 2nd object

# %%
""" change attribute value with the help of 2nd object """
print(p.name)
print(q.name)
q.name = 'ankit'
print(q.name)
print(p.name)
p = Person("Nitish", "India")

# nitish
# nitish
# ankit
# ankit
# Out:
# nitish
# nitish
# ankit
# ankit

# %% [markdown]
# ### Pass by reference

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print('Hi my name is',person.name,'and I am a',person.gender)
 
p = Person('nitish','male')
x = greet(p) #Hi my name is nitish and I am a male

# we can pass the class object p into the function in python
# Out:
# Hi my name is nitish and I am a male

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print('Hi my name is',person.name,'and I am a',person.gender)
  p1 = Person('ankit','male')
  return p1

p = Person('nitish','male')
x = greet(p)    # object is returning
print(x.name)
print(x.gender)

# Hi my name is nitish and I am a male
# ankit
# male
# Out:
# Hi my name is nitish and I am a male
# ankit
# male

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print(id(person))
  person.name = 'ankit'
  print(person.name)

p = Person('nitish','male')
print(id(p)) 
greet(p) # in this case we pass the id of object 
print(p.name)

# 2293788258192
# 2293788258192
# ankit
# ankit
# Out:
# 2293788258192
# 2293788258192
# ankit
# ankit

# %% [markdown]
# ### Object ki mutability

# %%
"""
--> if the object is mutable then address will same  ==> mutable --> address same 
--> if object is immutable then object is address will change ==> immutable --> address changes

--> in python the class data created their object is mutable means address will same , variable refere same address ,
    mean when you changes in object then the chenge occures in actual object 

"""


class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  person.name = 'ankit'
  return person

p = Person('nitish','male')
print(id(p))
p1 = greet(p)
print(id(p1))
# Out:
# 2306608400768
# 2306608400768

# %%
class Person:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender

# Function that modifies the object
def greet(person):
    person.name = 'ankit'
    return person

# Create object
p = Person('nitish', 'male')

# Print memory address of original object
print(id(p))       # Example: 140204885021728

# Pass to function which modifies it and returns it
p1 = greet(p)

# Print memory address of returned object
print(id(p1))      # Output: same as p's address

# %% [markdown]
# ---
#
# - ## `Encapsulation`
#
# -  campusx oop part2 at 01:20 minutes

# %% [markdown]
# ---
#
# 1. The Fundamental Problem (The "Why")
# To understand Encapsulation, we must first understand the chaos of direct access.
#
# Imagine you are a Senior Programmer who builds a critical class, like an Atm (from your notebook), that manages a user's money. You hand this class over to a "Junior Programmer" (or a user) to use in their code.
#
# The Vulnerability: If you leave the data (variables) open, the user can do anything they want with it.
#
# The Scenario:
#
# You created self.balance = 10000.
#
# The user/junior programmer writes obj.balance = "hehe" or obj.balance = -5000.
#
# The Crash: Your code expects a number to do math (subtraction for withdrawal). Since the user changed it to a string ("hehe"), your logic crashes (TypeError).
#
# The First Principle Truth: If you allow direct access to your internal data, you cannot guarantee the integrity of your object. Your code becomes fragile.

# %%
# instance var -> python tutor

"""
--> instance variable is variable which value vary base upon on every object 
--> Instance variable is dependent upon the object , if you create multiple object then values of instance variable changes
"""
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input  ## example of instance variable 
    self.country = country_input ## example of instance variable 

p1 = Person('nitish','india')
p2 = Person('steve','australia')

# %% [markdown]
# ### instance variable is variable which value vary base upon on every object

# %%
p1.name  # 'nitish' eg of intance of value name
# Out:
# 'nitish'

# %%
p2.name  #'steve' eg of intance of value name
# Out:
# 'steve'

# %%
#---------------Problem in  Without private variable ---------------------------------
class Atm:
  
  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin :
    2. Press 2 to change pin :
    3. Press 3 to check balance :
    4. Press 4 to withdraw :
    5. Anything else to exit :
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin :')
    self.pin = user_pin

    user_balance = int(input('enter balance :'))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()

  def change_pin():
    old_pin = input('enter old pin :')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin :')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else:
      print('nai karne de sakta re baba')
      self.menu()

  def check_balance(self):
    user_pin = input('enter your pin :')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin :')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount :'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.menu()

# %%
obj = Atm() #2470244689936


# 2293788256848

#     Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      1
# enter your pin : 1234
# enter balance : 10000
# pin created successfully

#     Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      3
# enter your pin : 1234
# your balance is  10000
# Out:
# 2293788256848
#     Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      1
# enter your pin : 1234
# enter balance : 10000
# pin created successfully
#     Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      3
# enter your pin : 1234
# your balance is  10000

# %%
obj.create_pin
obj.balance = 'hehehe'

# %% [markdown]
# #  Rough

# %%
class Atm:
    def __init__(self):
        self.__balance = 0

    def set_balance(self, amount):
        if amount >= 0:
            self.__balance = amount

    def get_balance(self):
        return self.__balance

# %%
obj.withdraw()  

# enter the pin : 1234
# enter the amount : 5000

# TypeError: '<=' not supported between instances of 'int' and 'str'
# Out:
# enter the pin : 1234
# enter the amount : 5000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 obj.withdraw()
#       3 """
#       4 TypeError
#       5 Cell In[8], line 1
#    (...)     16 TypeError: '<=' not supported between instances of 'int' and 'str'
#      17 """
#
# Cell In[37], line 67, in Atm.withdraw(self)
#      64 if user_pin == self.pin:
#      65   # allow to withdraw
#      66   amount = int(input('enter the amount :'))
# ---> 67   if amount <= self.balance:
#      68     self.balance = self.balance - amount
#      69     print('withdrawl successful.balance is',self.balance)
#
# TypeError: '<=' not supported between instances of 'int' and 'str'

# %%
"""---------------------  syntax for private attributes  -----------------------------------------------------
adding double under score before variable of function names 
"""
self.__balnce = 0 
def __display ( ):
    print ("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 """---------------------  syntax for private attributes  -----------------------------------------------------
#       2 adding double under score before variable of function names
#       3 """
# ----> 4 self.__balnce = 0
#       5 def __display ( ):
#       6     print ("hello")
#
# NameError: name 'self' is not defined

# %%
#---------------Problem in  Without private variable ---------------------------------

class Atm:
  
  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.__menu()

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin :
    2. Press 2 to change pin :
    3. Press 3 to check balance :
    4. Press 4 to withdraw :
    5. Anything else to exit :
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin :')
    self.pin = user_pin

    user_balance = int(input('enter balance :'))
    self.__balance = user_balance

    print('pin created successfully')
    self.__menu()

  def change_pin():
    old_pin = input('enter old pin :')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin :')
      self.pin = new_pin
      print('pin change successful')
      self.__menu()
    else:
      print('nai karne de sakta re baba')
      self.__menu()

  def check_balance(self):
    user_pin = input('enter your pin :')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin :')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount :'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.__menu()

# %%
obj = Atm()  
#2293788254832

# Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      1
# enter your pin : 1234
# enter balance : 10000
# pin created successfully

#     Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      3
# enter your pin : 1234
# your balance is  10000
# Out:
# 2363766977744
#     Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      1
# enter your pin : 1234
# enter balance : 10000
# pin created successfully
#     Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      3
# enter your pin : 1234
# your balance is  10000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 obj = Atm()
# ----> 2 obj.__balance()
#       3 #2293788254832
#       4
#       5 # Hi how can I help you?
#    (...)     23 # enter your pin : 1234
#      24 # your balance is  10000
#
# AttributeError: 'Atm' object has no attribute '__balance'

# %%
obj.balance()
# AttributeError: 'Atm' object has no attribute 'balance'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 obj.balance()
#
# AttributeError: 'Atm' object has no attribute 'balance'

# %%
obj.__balance()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 obj.__balance()
#
# AttributeError: 'Atm' object has no attribute '__balance'

# %%
obj.create_pin()
obj.__balance = 'hehhehe'


# enter your pin : 1234
# enter balance : 10000
# pin created successfully

#     Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      3
# enter your pin : 1234
# your balance is  10000

"""
obj.__balance == obj.__Atm__balance

In the python nothing is truely private , its understood between the programmer to not used it """
# Out:
# enter your pin : 1234
# enter balance : 10000
# pin created successfully
#     Hi how can I help you?
#     1. Press 1 to create pin :
#     2. Press 2 to change pin :
#     3. Press 3 to check balance :
#     4. Press 4 to withdraw :
#     5. Anything else to exit :
#      3
# enter your pin : 1234
# your balance is  10000
# '\nobj.__balance == obj.__Atm__balance\n\nIn the python nothing is truely private , its understood between the programmer to not used it '

# %% [markdown]
# ---
# - ### in this below eg p1 if someone know my private variable in somehow and change it to something like  `p1.__name='ankit'`  it not effect the original private variable in the class , bcoz python create two different variable in the memory address

# %%
## in this below eg p1 if someone know my private variable in somehow and change it to something like  `p1.__name='ankit'`  
## it not effect the original private variable in the class , bcoz python create two different variable in the memory address 
## p1 -->> _person__name ="nitish"
## p1 -->> __name = "ankit"

class Person :
    def __init__( self ) :
        self.__name = 'nitish'

p1 = Person()
print(id (p1))
# Out:
# 2306608406816
# nitish

# %%
p1.__name='ankit'
print (id( p1.__name))
# Out:
# 2306608475536

# %% [markdown]
# ---
# - ### obj.__balance == obj.__Atm__balance In the python nothing is truely private , its understood between the programmer to not used it

# %%
p1._Person__name = "ankit"
print (( p1._Person__name))
# Out:
# ankit

# %% [markdown]
# ---
# - ## Private variable or attributes :  `getter and setter`

# %%
"""-------------------------- Private variable or attributes :  getter and setter  ------------------------------------------------------------------------"""
class Atm:

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()
    
#----------- getter --------------------
  def get_balance(self):
    return self.__balance

#----------- setter --------------------
  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin :
    2. Press 2 to change pin :
    3. Press 3 to check balance :
    4. Press 4 to withdraw :
    5. Anything else to exit !
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin :')
    self.pin = user_pin

    user_balance = int(input('enter balance :'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin :')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin :')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin :')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin :')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount :'))
      if amount <= self.__balance:    
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj = Atm ()
# 2363766972704
# Out:
# 2363766972704

# %%
obj.get_balance()
# Out:
# 0

# %%
obj.set_balance('hehehe')

# beta bahot maarenge
# Out:
# beta bahot maarenge

# %%
obj.set_balance(1000)

# %%
obj.get_balance()
# Out:
# 1000

# %%
obj.withdraw()

# enter the pin : 1234
# sale chor
# Out:
# enter the pin : 1234
# sale chor

# %% [markdown]
# ### Collection of objects

# %%
# list of objects

class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

L = [p1,p2,p3]

print ( L)

# [<__main__.Person object at 0x000002265B7D8830>, <__main__.Person object at 0x000002265BE1D310>, <__main__.Person object at 0x000002265BE1D1D0>]
# Out:
# [<__main__.Person object at 0x000002265B7D8830>, <__main__.Person object at 0x000002265BE1D310>, <__main__.Person object at 0x000002265BE1D1D0>]

# %%
# dict of objects
# list of objects
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

d = {'p1':p1,'p2':p2,'p3':p3}

for i in d:
  print(d[i].gender)


# male
# male
# female
# Out:
# male
# male
# female

# %%
for i in d:
  print(i)
# Out:
# p1
# p2
# p3

# %%
for i in d:
  print(d[i].gender )
# Out:
# male
# male
# female

# %% [markdown]
# ## HW Quest
#  ### make person class and stored in set

# %% [markdown]
# ### Static Variables(Vs Instance variables)

# %%
# need for static vars
class Atm:


  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = 0
    self.cid+=1
   
    #self.menu()

  # utility functions
  # @staticmethod
  # def get_counter():
  #   return Atm.__counter


  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
c1 = Atm()
# Out:
# 2363766965648

# %%
c2 = Atm()
# Out:
# 2363773540368

# %%
c3 = Atm()
# Out:
# 2363766827184

# %%
c1.cid
# Out:
# 1

# %%
c2.cid
# Out:
# 1

# %%
c3.cid
# Out:
# 1

# %% [markdown]
# ## As we see that the instance values of each and every object different so the counter is always become 1 each and every times , that why we need static values
#
# ##  Instance varible is created  for object and fetch by object.variable_name in the constructor but static variable is created within the block class  and fetch with Class_name.Varible name

# %%
# How to defined statics variable 
statics variable always be defined outside the constructor and  after the class name 

# syntax for statics variable 
class Atm :
    statics_name = values

# how to access of statics variable -->>  with class name
    
    Atm.statics_name

# %%
# need for static vars
class Atm:

  __counter = 1

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = Atm.__counter
    Atm.__counter = Atm.__counter + 1
    #self.menu()

  # utility functions -->> its not required any arument , its do small things
  @staticmethod
  def get_counter():
    return Atm.__counter


  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
c1 = Atm()
c2 = Atm()
c3 = Atm()
# 2363766969680
# 2363773134928
# 2363773125968
# Out:
# 2713070803936
# 2713074422864
# 2713074422544

# %%
c1.cid
# Out:
# 1

# %%
c2.cid
# Out:
# 2

# %%
c3.cid
# Out:
# 3

# %%
c4 = Atm()
c4.get_counter()
# Out:
# 2713067413296
# 6

# %% [markdown]
# ---
#
# -  ###     Univercity , uni address , batch name --> are the same bcoz it is not different they are same  but student name , roll no , marks , student parents -->> are different that is why we have to used it "instance variable"

# %% [markdown]
# ### Static methods

# %% [markdown]
# ##### Points to remember about static
#
# - Static attributes are created at class level.
# - Static attributes are accessed using ClassName.
# - Static attributes are object independent. We can access them without creating instance (object) of the class in which they are defined.
# - The value stored in static attribute is shared between all instances(objects) of the class in which the static attribute is defined.

# %%
class Lion:
  __water_source="well in the circus"

  def __init__(self,name, gender):
      self.__name=name
      self.__gender=gender

  def drinks_water(self):
      print(self.__name,
      "drinks water from the",Lion.__water_source)

  @staticmethod
  def get_water_source():
      return Lion.__water_source

simba=Lion("Simba","Male")
simba.drinks_water()
print( "Water source of lions:",Lion.get_water_source())
# Out:
# Simba drinks water from the well in the circus
# Water source of lions: well in the circus
