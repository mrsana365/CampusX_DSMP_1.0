# %%
# 1. Find the kth smallest item from a list

L = [12,23,1,4,56,34,22,3]
min = L[0] 

for i in range ( 0 , len(L)):
    if min > L[i] :
        min = L[i]

print ( min )
# Out:
# 1

# %%
L = [12,23,1,4,56,34,22,3]
print ( L.min())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 L = [12,23,1,4,56,34,22,3]
# ----> 2 print ( L.min())
#
# AttributeError: 'list' object has no attribute 'min'

# %%
# 1. Find the kth largest item from a list

L = [12,23,1,4,56,34,22,3]
max = L[0] 

for i in range ( 0 , len(L)):
    if min < L[i] :
        min = L[i]

print ( min )
# Out:
# 56

# %%
# 1. Find the kth largest item from a list

L = [12,23,1,4,56,34,22,3]

L.sort( reverse=False)
print( L )
L[ -3 ]
# Out:
# [1, 3, 4, 12, 22, 23, 34, 56]
# 23

# %%
# 2. Check if an array is sorted
L = [1,2,30,4,5]

flag = False
min = L[0]

for i in range( 0 , len (L)) :
    if min >= L[i]:
        min = L[i]
        flag = True

print( flag)
# Out:
# True
